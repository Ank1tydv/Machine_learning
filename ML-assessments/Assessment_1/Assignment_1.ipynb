# %% [markdown]
# # Exploring Data Visualization in Python with Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt

# %%
iris_data= pd.read_csv('D:\MlOps\ML_ajay_sir\ML-assessments\Assessment_1\iris_data.csv')

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Line plot b/w each feature and species

# %%
# A Line plot b/w sepal_length and species

sorted_data= iris_data.sort_values('sepal_length')
plt.plot(sorted_data['sepal_length'],sorted_data['species'])
#plt.plot(iris_data['sepal_length'],sorted_data['species'])

plt.xlabel('sepal_length',fontsize=12,color='red')
plt.ylabel('species',fontsize=12,color='green')
plt.title('Line plot b/w sepal_length and species', fontsize=16,fontweight='bold',color='Purple')
# Out:
# Text(0.5, 1.0, 'Line plot b/w sepal_length and species')

# %%
# A Line plot b/w sepal_width and species
sorted_data= iris_data.sort_values('sepal_width')
plt.plot(sorted_data['sepal_width'],sorted_data['species'])
plt.xlabel('sepal_width',fontsize=12,color='red')
plt.ylabel('species',fontsize=12,color='green')
plt.title('Line plot b/w sepal_width and species', fontsize=16,fontweight='bold',color='Purple')
# Out:
# Text(0.5, 1.0, 'Line plot b/w sepal_width and species')

# %%
# A Line plot b/w petal_length and species
sorted_data= iris_data.sort_values('petal_length')
plt.plot(sorted_data['petal_length'],sorted_data['species'])
plt.xlabel('petal_length',fontsize=12,color='red')
plt.ylabel('petal_length',fontsize=12,color='green')
plt.title('Line plot b/w petal_length and species',fontsize=16,fontweight='bold',color='Purple')
# Out:
# Text(0.5, 1.0, 'Line plot b/w petal_length and species')

# %%
# A Line plot b/w petal_width and species
sorted_data= iris_data.sort_values('petal_width')
plt.plot(sorted_data['petal_width'],sorted_data['species'])
plt.xlabel('petal_width',fontsize=12,color='red')
plt.ylabel('petal_width',fontsize=12,color='green')
plt.title('Line plot b/w petal_width and species',fontsize=16,fontweight='bold',color='Purple')
# Out:
# Text(0.5, 1.0, 'Line plot b/w petal_width and species')

# %% [markdown]
# # Scatter plot b/w each feature and species

# %%
# A Scatter plot b/w sepal_length and species

sorted_data= iris_data.sort_values('sepal_length')
plt.scatter(sorted_data['sepal_length'],sorted_data['species'])
#plt.scatterw(iris_data['sepal_length'],sorted_data['species'])

plt.xlabel('sepal_length',fontsize=12,color='red')
plt.ylabel('species',fontsize=12,color='green')
plt.title('Scatter plot b/w sepal_length and species', fontsize=16,fontweight='bold',color='Purple')
# Out:
# Text(0.5, 1.0, 'Scatter plot b/w sepal_length and species')

# %%
# A Scatter plot b/w sepal_width and species
sorted_data= iris_data.sort_values('sepal_width')
plt.scatter(sorted_data['sepal_width'],sorted_data['species'])
plt.xlabel('sepal_width',fontsize=12,color='red')
plt.ylabel('species',fontsize=12,color='green')
plt.title('Scatter plot b/w sepal_width and species', fontsize=16,fontweight='bold',color='Purple')
# Out:
# Text(0.5, 1.0, 'Scatter plot b/w sepal_width and species')

# %%
# A Scatter plot b/w petal_length and species
sorted_data= iris_data.sort_values('petal_length')
plt.scatter(sorted_data['petal_length'],sorted_data['species'])
plt.xlabel('petal_length',fontsize=12,color='red')
plt.ylabel('petal_length',fontsize=12,color='green')
plt.title('Scatter plot b/w petal_length and species',fontsize=16,fontweight='bold',color='Purple')
# Out:
# Text(0.5, 1.0, 'Scatter plot b/w petal_length and species')

# %%
# A Scatter plot b/w petal_width and species
sorted_data= iris_data.sort_values('petal_width')
plt.scatter(sorted_data['petal_width'],sorted_data['species'])
plt.xlabel('petal_width',fontsize=12,color='red')
plt.ylabel('petal_width',fontsize=12,color='green')
plt.title('Scatter plot b/w petal_width and species',fontsize=16,fontweight='bold',color='Purple')
# Out:
# Text(0.5, 1.0, 'Scatter plot b/w petal_width and species')

# %% [markdown]
# # Histogram plot b/w each feature and species

# %%
import seaborn as sns

# %%
# A Histogram plot b/w sepal_length and species

iris_col = iris_data.columns[:-1]
plt.figure(figsize=(12, 10))

for i, col_name in enumerate(iris_col,1):
    plt.subplot(2, 2, i)
    sns.histplot(data=iris_data, x=col_name, hue='species', bins=20, palette='pastel', multiple='stack')
    plt.xlabel(col_name, fontsize=12, color='red')
    plt.ylabel('value', fontsize=12, color='green')
    plt.title(f'Histogram of {col_name}', fontsize=16, fontweight='bold', color='Purple')

# %% [markdown]
# # Part 2: Handling Null Values in Python with Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib as mp

# %%
data= pd.read_csv("D:\MlOps\ML_ajay_sir\ML-assessments\Assessment_1\housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# here we display the counts of null row in each column.

data.isnull().sum()
# Out:
# longitude                  0
# latitude                   0
# housing_median_age         0
# total_rooms                0
# total_bedrooms           207
# population                 0
# households                 0
# median_income              0
# median_house_value         0
# ocean_proximity            0
# total_bedrooms_medium      0
# total_bedrooms_mediam      0
# total_bedrooms_median      0
# dtype: int64

# %%
data_test= data[['total_bedrooms']]

# %%
# To fill the total_bedrooms col null rows with medium value of the total_bedrooms col

data_test['total_bedrooms_median']= data_test['total_bedrooms'].fillna(data_test['total_bedrooms'].median())
# Out:
# C:\Users\Ankit Yadav\AppData\Local\Temp\ipykernel_50980\1745131953.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['total_bedrooms_median']= data_test['total_bedrooms'].fillna(data_test['total_bedrooms'].median())

# %%
data_test
# Out:
#        total_bedrooms  total_bedrooms_median
# 0               129.0                  129.0
# 1              1106.0                 1106.0
# 2               190.0                  190.0
# 3               235.0                  235.0
# 4               280.0                  280.0
# ...               ...                    ...
# 20635           374.0                  374.0
# 20636           150.0                  150.0
# 20637           485.0                  485.0
# 20638           409.0                  409.0
# 20639           616.0                  616.0
#
# [20640 rows x 2 columns]

# %%
# To fill the total_bedrooms col null rows with Interpolate Method 
data_test['total_bedrooms_interpolate']= data_test['total_bedrooms'].fillna(data_test['total_bedrooms'].interpolate())
# Out:
# C:\Users\Ankit Yadav\AppData\Local\Temp\ipykernel_50980\3348219231.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['total_bedrooms_interpolate']= data_test['total_bedrooms'].fillna(data_test['total_bedrooms'].interpolate())

# %%
std_info=data_test.std()

# %%
std_info
# Out:
# total_bedrooms                421.385070
# total_bedrooms_median         419.391878
# total_bedrooms_interpolate    420.424655
# dtype: float64

# %%
for col,count in zip(std_info.index,std_info.values):
    print(f"{col}=>{std_info['total_bedrooms']-count}")
# Out:
# total_bedrooms=>0.0
# total_bedrooms_median=>1.9931921523442497
# total_bedrooms_interpolate=>0.9604154118256361

# %%
'''
 On the basis of Standard deviation we get to know which method is best suited for filling the Null values.
So, here on the basis of above result, Interpolate method is more effective then median.
'''
# Out:
# '\n On the basis of Standard deviation we get to know which method is best suited for filling the Null values.\nSo, here on the basis of above resul Interpolate method is more effective then median.\n'

# %%
# Visualize the interpolated values using a line plot

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data_test['total_bedrooms_interpolate'])

# %%
plt.plot(data_test['total_bedrooms_interpolate'], marker='o')
